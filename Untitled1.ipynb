# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
read_csv = pd.read_csv("C:\Users\musfik\Downloads\mlllllll\Housing - Copy.csv")
read_csv.shape
# Out:
# (545, 13)

# %%
read_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
# price               516 non-null float64
# area                449 non-null float64
# bedrooms            534 non-null float64
# bathrooms           545 non-null int64
# stories             545 non-null int64
# mainroad            545 non-null object
# guestroom           545 non-null object
# basement            10 non-null object
# hotwaterheating     545 non-null object
# airconditioning     545 non-null object
# parking             545 non-null int64
# prefarea            545 non-null object
# furnishingstatus    120 non-null object
# dtypes: float64(3), int64(3), object(7)
# memory usage: 55.4+ KB

# %%
read_csv.head(6)
# Out:
#         price    area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0  13300000.0  7420.0       4.0          2        3      yes        no
# 1  12250000.0  8960.0       4.0          4        4      yes        no
# 2  12250000.0     NaN       3.0          2        2      yes        no
# 3  12215000.0     NaN       4.0          2        2      yes        no
# 4  11410000.0     NaN       4.0          1        2      yes       yes
# 5  10850000.0     NaN       3.0          3        1      yes        no
#
#   basement hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0      NaN              no             yes        2      yes        furnished
# 1      NaN              no             yes        3       no        furnished
# 2      NaN              no              no        2      yes              NaN
# 3      NaN              no             yes        3      yes              NaN
# 4      NaN              no             yes        2       no              NaN
# ...

# %%
read_csv.tail(6)
# Out:
#          price    area  bedrooms  bathrooms  stories mainroad guestroom  \
# 539  1855000.0  2990.0       2.0          1        1       no        no
# 540  1820000.0  3000.0       2.0          1        1      yes        no
# 541  1767150.0  2400.0       3.0          1        1       no        no
# 542  1750000.0  3620.0       2.0          1        1      yes        no
# 543  1750000.0  2910.0       3.0          1        1       no        no
# 544  1750000.0  3850.0       3.0          1        2      yes        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# 539       no              no              no        1       no
# 540      yes              no              no        2       no
# 541       no              no              no        0       no
# 542       no              no              no        0       no
# 543       no              no              no        0       no
# 544       no              no              no        0       no
#
# ...

# %%
read_csv.isnull().sum()
# Out:
# price                29
# area                 96
# bedrooms             11
# bathrooms             0
# stories               0
# mainroad              0
# guestroom             0
# basement            535
# hotwaterheating       0
# airconditioning       0
# parking               0
# prefarea              0
# furnishingstatus    425
# dtype: int64

# %%
read_csv.isnull().sum().sum()
# Out:
# 1096

# %%
var_per = read_csv.isnull().sum()/read_csv.shape[0]*100
var_per
# Out:
# price                5.321101
# area                17.614679
# bedrooms             2.018349
# bathrooms            0.000000
# stories              0.000000
# mainroad             0.000000
# guestroom            0.000000
# basement            98.165138
# hotwaterheating      0.000000
# airconditioning      0.000000
# parking              0.000000
# prefarea             0.000000
# furnishingstatus    77.981651
# dtype: float64

# %%
read_wdrop = var_per[var_per>40].keys()
read_wdrop
# Out:
# Index([u'basement', u'furnishingstatus'], dtype='object')

# %%
drop_40p = read_csv.drop(columns=read_wdrop)
drop_40p
# Out:
#           price     area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000.0   7420.0       4.0          2        3      yes        no
# 1    12250000.0   8960.0       4.0          4        4      yes        no
# 2    12250000.0      NaN       3.0          2        2      yes        no
# 3    12215000.0      NaN       4.0          2        2      yes        no
# 4    11410000.0      NaN       4.0          1        2      yes       yes
# 5    10850000.0      NaN       3.0          3        1      yes        no
# 6    10150000.0      NaN       4.0          3        4      yes        no
# 7    10150000.0      NaN       5.0          3        2      yes        no
# 8     9870000.0   8100.0       NaN          1        2      yes       yes
# 9     9800000.0   5750.0       NaN          2        4      yes       yes
# 10    9800000.0  13200.0       NaN          1        2      yes        no
# 11    9681000.0   6000.0       NaN          3        2      yes       yes
# ...

# %%
sns.heatmap(drop_40p.isnull())

# %%
int_float_value = drop_40p.select_dtypes(include=["int64","float64"])
int_float_values = drop_40p.select_dtypes(include=["int64","float64"]).columns

# %%
int_float_value.fillna(int_float_value.mean())
# Out:
#           price          area  bedrooms  bathrooms  stories  parking
# 0    13300000.0   7420.000000  4.000000          2        3        2
# 1    12250000.0   8960.000000  4.000000          4        4        3
# 2    12250000.0   4984.706013  3.000000          2        2        2
# 3    12215000.0   4984.706013  4.000000          2        2        3
# 4    11410000.0   4984.706013  4.000000          1        2        2
# 5    10850000.0   4984.706013  3.000000          3        1        2
# 6    10150000.0   4984.706013  4.000000          3        4        2
# 7    10150000.0   4984.706013  5.000000          3        2        0
# 8     9870000.0   8100.000000  2.953184          1        2        2
# 9     9800000.0   5750.000000  2.953184          2        4        1
# 10    9800000.0  13200.000000  2.953184          1        2        2
# 11    9681000.0   6000.000000  2.953184          3        2        2
# 12    9310000.0   6550.000000  2.953184          2        2        1
# ...

# %%
drop_40p.isnull().sum()
# Out:
# price              29
# area               96
# bedrooms           11
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# dtype: int64

# %%
int_float_value.fillna(int_float_value.median())
# Out:
#           price     area  bedrooms  bathrooms  stories  parking
# 0    13300000.0   7420.0       4.0          2        3        2
# 1    12250000.0   8960.0       4.0          4        4        3
# 2    12250000.0   4500.0       3.0          2        2        2
# 3    12215000.0   4500.0       4.0          2        2        3
# 4    11410000.0   4500.0       4.0          1        2        2
# 5    10850000.0   4500.0       3.0          3        1        2
# 6    10150000.0   4500.0       4.0          3        4        2
# 7    10150000.0   4500.0       5.0          3        2        0
# 8     9870000.0   8100.0       3.0          1        2        2
# 9     9800000.0   5750.0       3.0          2        4        1
# 10    9800000.0  13200.0       3.0          1        2        2
# 11    9681000.0   6000.0       3.0          3        2        2
# 12    9310000.0   6550.0       3.0          2        2        1
# 13    9240000.0   3500.0       3.0          2        2        2
# ...

# %%
int_float_value.fillna(int_float_value.mode())
# Out:
#           price     area  bedrooms  bathrooms  stories  parking
# 0    13300000.0   7420.0       4.0          2        3        2
# 1    12250000.0   8960.0       4.0          4        4        3
# 2    12250000.0      NaN       3.0          2        2        2
# 3    12215000.0      NaN       4.0          2        2        3
# 4    11410000.0      NaN       4.0          1        2        2
# 5    10850000.0      NaN       3.0          3        1        2
# 6    10150000.0      NaN       4.0          3        4        2
# 7    10150000.0      NaN       5.0          3        2        0
# 8     9870000.0   8100.0       NaN          1        2        2
# 9     9800000.0   5750.0       NaN          2        4        1
# 10    9800000.0  13200.0       NaN          1        2        2
# 11    9681000.0   6000.0       NaN          3        2        2
# 12    9310000.0   6550.0       NaN          2        2        1
# 13    9240000.0   3500.0       NaN          2        2        2
# ...

# %%
int_float_value
# Out:
#           price     area  bedrooms  bathrooms  stories  parking
# 0    13300000.0   7420.0       4.0          2        3        2
# 1    12250000.0   8960.0       4.0          4        4        3
# 2    12250000.0      NaN       3.0          2        2        2
# 3    12215000.0      NaN       4.0          2        2        3
# 4    11410000.0      NaN       4.0          1        2        2
# 5    10850000.0      NaN       3.0          3        1        2
# 6    10150000.0      NaN       4.0          3        4        2
# 7    10150000.0      NaN       5.0          3        2        0
# 8     9870000.0   8100.0       NaN          1        2        2
# 9     9800000.0   5750.0       NaN          2        4        1
# 10    9800000.0  13200.0       NaN          1        2        2
# 11    9681000.0   6000.0       NaN          3        2        2
# 12    9310000.0   6550.0       NaN          2        2        1
# 13    9240000.0   3500.0       NaN          2        2        2
# ...

# %%
cleandtype = drop_40p.fillna(int_float_value.mean())

# %%
cleandtype.isnull().sum()
# Out:
# price              0
# area               0
# bedrooms           0
# bathrooms          0
# stories            0
# mainroad           0
# guestroom          0
# hotwaterheating    0
# airconditioning    0
# parking            0
# prefarea           0
# dtype: int64

# %%
sns.heatmap(cleandtype.isnull())

# %%
initr = cleandtype.select_dtypes(include=["float64","int64"]) 
init = cleandtype.select_dtypes(include=["float64","int64"]).columns
display(initr,init)
# Out:
#           price          area  bedrooms  bathrooms  stories  parking
# 0    13300000.0   7420.000000  4.000000          2        3        2
# 1    12250000.0   8960.000000  4.000000          4        4        3
# 2    12250000.0   4984.706013  3.000000          2        2        2
# 3    12215000.0   4984.706013  4.000000          2        2        3
# 4    11410000.0   4984.706013  4.000000          1        2        2
# 5    10850000.0   4984.706013  3.000000          3        1        2
# 6    10150000.0   4984.706013  4.000000          3        4        2
# 7    10150000.0   4984.706013  5.000000          3        2        0
# 8     9870000.0   8100.000000  2.953184          1        2        2
# 9     9800000.0   5750.000000  2.953184          2        4        1
# 10    9800000.0  13200.000000  2.953184          1        2        2
# 11    9681000.0   6000.000000  2.953184          3        2        2
# 12    9310000.0   6550.000000  2.953184          2        2        1
# ...

# %%
plt.figure(figsize=(25,25))
for i in range(len(init)):
    plt.subplot(4,9,i+1)
    sns.distplot(cleandtype[init[i]],bins=20)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\Users\musfik\Downloads\mlllllll\Housing - Copy.csv")
df.shape
# Out:
# (545, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
# price               516 non-null float64
# area                449 non-null float64
# bedrooms            534 non-null float64
# bathrooms           545 non-null int64
# stories             545 non-null int64
# mainroad            545 non-null object
# guestroom           545 non-null object
# basement            10 non-null object
# hotwaterheating     545 non-null object
# airconditioning     545 non-null object
# parking             545 non-null int64
# prefarea            545 non-null object
# furnishingstatus    120 non-null object
# dtypes: float64(3), int64(3), object(7)
# memory usage: 55.4+ KB

# %%
df.isnull().sum()
# Out:
# price                29
# area                 96
# bedrooms             11
# bathrooms             0
# stories               0
# mainroad              0
# guestroom             0
# basement            535
# hotwaterheating       0
# airconditioning       0
# parking               0
# prefarea              0
# furnishingstatus    425
# dtype: int64

# %%
var_num = df.isnull().sum()/df.shape[0]*100
var_num
# Out:
# price                5.321101
# area                17.614679
# bedrooms             2.018349
# bathrooms            0.000000
# stories              0.000000
# mainroad             0.000000
# guestroom            0.000000
# basement            98.165138
# hotwaterheating      0.000000
# airconditioning      0.000000
# parking              0.000000
# prefarea             0.000000
# furnishingstatus    77.981651
# dtype: float64

# %%
drop_40 = var_num[var_num>40].keys()
drop_40
# Out:
# Index([u'basement', u'furnishingstatus'], dtype='object')

# %%
droped_40 = df.drop(columns=drop_40)

# %%
sns.heatmap(droped_40.isnull())

# %%
int_float_defiend = droped_40.select_dtypes(include=["int64","float64"])
int_float_defiend1 = droped_40.select_dtypes(include=["int64","float64"]).columns
clean_int = int_float_defiend.fillna(int_float_defiend.mean())

# %%
sns.heatmap(clean_int.isnull())

# %%
int_float_df = df.select_dtypes(include=["int64","float64"])
int_float_df1 = df.select_dtypes(include=["int64","float64"]).columns

# %%
plt.figure(figsize=(25,25))
for i in range(len(int_float_defiend1)):
    plt.subplot(5,9,i+1)
    sns.distplot([clean_int[int_float_defiend1[i]]],bins=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-118-4f96cb7b0685> in <module>()
#       3     plt.subplot(5,9,i+1)
#       4     sns.distplot(clean_int[int_float_defiend1[i]],bins=20)
# ----> 5     sns.distplot(int_float_df[int_float_df1[i]],bins=20)
#       6 plt.show()
#
# C:\ProgramData\Anaconda2\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     223         hist_color = hist_kws.pop("color", color)
#     224         ax.hist(a, bins, orientation=orientation,
# --> 225                 color=hist_color, **hist_kws)
#     226         if hist_color != color:
#     227             hist_kws["color"] = hist_color
#
# C:\ProgramData\Anaconda2\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
# ...

# %%
int_float_defiend
# Out:
#           price     area  bedrooms  bathrooms  stories  parking
# 0    13300000.0   7420.0       4.0          2        3        2
# 1    12250000.0   8960.0       4.0          4        4        3
# 2    12250000.0      NaN       3.0          2        2        2
# 3    12215000.0      NaN       4.0          2        2        3
# 4    11410000.0      NaN       4.0          1        2        2
# 5    10850000.0      NaN       3.0          3        1        2
# 6    10150000.0      NaN       4.0          3        4        2
# 7    10150000.0      NaN       5.0          3        2        0
# 8     9870000.0   8100.0       NaN          1        2        2
# 9     9800000.0   5750.0       NaN          2        4        1
# 10    9800000.0  13200.0       NaN          1        2        2
# 11    9681000.0   6000.0       NaN          3        2        2
# 12    9310000.0   6550.0       NaN          2        2        1
# 13    9240000.0   3500.0       NaN          2        2        2
# ...

# %%
int_float_df
# Out:
#           price     area  bedrooms  bathrooms  stories  parking
# 0    13300000.0   7420.0       4.0          2        3        2
# 1    12250000.0   8960.0       4.0          4        4        3
# 2    12250000.0      NaN       3.0          2        2        2
# 3    12215000.0      NaN       4.0          2        2        3
# 4    11410000.0      NaN       4.0          1        2        2
# 5    10850000.0      NaN       3.0          3        1        2
# 6    10150000.0      NaN       4.0          3        4        2
# 7    10150000.0      NaN       5.0          3        2        0
# 8     9870000.0   8100.0       NaN          1        2        2
# 9     9800000.0   5750.0       NaN          2        4        1
# 10    9800000.0  13200.0       NaN          1        2        2
# 11    9681000.0   6000.0       NaN          3        2        2
# 12    9310000.0   6550.0       NaN          2        2        1
# 13    9240000.0   3500.0       NaN          2        2        2
# ...

# %%
int_float_df1
# Out:
# Index([u'price', u'area', u'bedrooms', u'bathrooms', u'stories', u'parking'], dtype='object')
