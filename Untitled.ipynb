# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
read_csv = pd.read_csv("C:\Users\musfik\Downloads\mlllllll\Housing - Copy.csv")
read_csv
# Out:
#           price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000.0   7420       4.0          2        3      yes        no
# 1    12250000.0   8960       4.0          4        4      yes        no
# 2    12250000.0   9960       3.0          2        2      yes        no
# 3    12215000.0   7500       4.0          2        2      yes        no
# 4    11410000.0   7420       4.0          1        2      yes       yes
# 5    10850000.0   7500       3.0          3        1      yes        no
# 6    10150000.0   8580       4.0          3        4      yes        no
# 7    10150000.0  16200       5.0          3        2      yes        no
# 8     9870000.0   8100       NaN          1        2      yes       yes
# 9     9800000.0   5750       NaN          2        4      yes       yes
# 10    9800000.0  13200       NaN          1        2      yes        no
# 11    9681000.0   6000       NaN          3        2      yes       yes
# ...

# %%
read_csv.shape
# Out:
# (545, 13)

# %%
read_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
# price               516 non-null float64
# area                545 non-null int64
# bedrooms            534 non-null float64
# bathrooms           545 non-null int64
# stories             545 non-null int64
# mainroad            545 non-null object
# guestroom           545 non-null object
# basement            10 non-null object
# hotwaterheating     545 non-null object
# airconditioning     545 non-null object
# parking             545 non-null int64
# prefarea            545 non-null object
# furnishingstatus    120 non-null object
# dtypes: float64(2), int64(4), object(7)
# memory usage: 55.4+ KB

# %%
read_csv.isnull()
# Out:
#      price   area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    False  False     False      False    False     False      False
# 1    False  False     False      False    False     False      False
# 2    False  False     False      False    False     False      False
# 3    False  False     False      False    False     False      False
# 4    False  False     False      False    False     False      False
# 5    False  False     False      False    False     False      False
# 6    False  False     False      False    False     False      False
# 7    False  False     False      False    False     False      False
# 8    False  False      True      False    False     False      False
# 9    False  False      True      False    False     False      False
# 10   False  False      True      False    False     False      False
# 11   False  False      True      False    False     False      False
# 12   False  False      True      False    False     False      False
# ...

# %%
read_csv.isnull().sum()
# Out:
# price                29
# area                  0
# bedrooms             11
# bathrooms             0
# stories               0
# mainroad              0
# guestroom             0
# basement            535
# hotwaterheating       0
# airconditioning       0
# parking               0
# prefarea              0
# furnishingstatus    425
# dtype: int64

# %%
number_of_nullcsv = read_csv.isnull()

# %%
sns.heatmap(number_of_nullcsv)

# %%
null_var = read_csv.isnull().sum()/read_csv.shape[0] *100
null_var
# Out:
# price                5.321101
# area                 0.000000
# bedrooms             2.018349
# bathrooms            0.000000
# stories              0.000000
# mainroad             0.000000
# guestroom            0.000000
# basement            98.165138
# hotwaterheating      0.000000
# airconditioning      0.000000
# parking              0.000000
# prefarea             0.000000
# furnishingstatus    77.981651
# dtype: float64

# %%
the_collumns_40p = null_var[null_var>40].keys()
the_collumns_40p
print(the_collumns_40p)
# Out:
# Index([u'basement', u'furnishingstatus'], dtype='object')

# %%
drop_Columns = read_csv.drop(columns=the_collumns_40p)
drop_Columns
# Out:
#           price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000.0   7420       4.0          2        3      yes        no
# 1    12250000.0   8960       4.0          4        4      yes        no
# 2    12250000.0   9960       3.0          2        2      yes        no
# 3    12215000.0   7500       4.0          2        2      yes        no
# 4    11410000.0   7420       4.0          1        2      yes       yes
# 5    10850000.0   7500       3.0          3        1      yes        no
# 6    10150000.0   8580       4.0          3        4      yes        no
# 7    10150000.0  16200       5.0          3        2      yes        no
# 8     9870000.0   8100       NaN          1        2      yes       yes
# 9     9800000.0   5750       NaN          2        4      yes       yes
# 10    9800000.0  13200       NaN          1        2      yes        no
# 11    9681000.0   6000       NaN          3        2      yes       yes
# ...

# %%
read_csv.shape
# Out:
# (545, 13)

# %%
sns.heatmap(drop_Columns.isnull())

# %%
drop_rows = drop_Columns.dropna()

# %%
drop_rows
# Out:
#           price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000.0   7420       4.0          2        3      yes        no
# 1    12250000.0   8960       4.0          4        4      yes        no
# 2    12250000.0   9960       3.0          2        2      yes        no
# 3    12215000.0   7500       4.0          2        2      yes        no
# 4    11410000.0   7420       4.0          1        2      yes       yes
# 5    10850000.0   7500       3.0          3        1      yes        no
# 6    10150000.0   8580       4.0          3        4      yes        no
# 7    10150000.0  16200       5.0          3        2      yes        no
# 19    8855000.0   6420       3.0          2        2      yes        no
# 20    8750000.0   4320       3.0          1        2      yes        no
# 21    8680000.0   7155       3.0          2        1      yes       yes
# 22    8645000.0   8050       3.0          1        1      yes       yes
# ...

# %%
sns.heatmap(drop_rows.isnull())

# %%
int_values_columns =drop_rows.select_dtypes(include=["int64","float64"]).columns
int_values_columns
int_values_columns_read_csv = read_csv.select_dtypes(include=["int64","float64"]).columns
display(int_values_columns,int_values_columns_read_csv,len(int_values_columns_read_csv),len(int_values_columns))
# Out:
# Index([u'price', u'area', u'bedrooms', u'bathrooms', u'stories', u'parking'], dtype='object')
# Index([u'price', u'area', u'bedrooms', u'bathrooms', u'stories', u'parking'], dtype='object')
# 6
# 6

# %%
number_of_intfloat = len(int_values_columns)
type(number_of_intfloat)
# Out:
# int

# %%
plt.figure(figsize=(25,25))
for i in range(number_of_intfloat):
    plt.subplot(9,4,i+1)
    plt.hist(drop_rows[int_values_columns[i]])

# %%
plt.figure(figsize=(25,25))
for i in range(number_of_intfloat):
    plt.subplot(9,4,i+1)
    sns.distplot(drop_rows[int_values_columns[i]],bins=20)
#     plt.distplot(read_csv[str(int_values_columns_read_csv[i])],bins=20)
#     plt.show()
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
read_csv = pd.read_csv("C:\Users\musfik\Downloads\mlllllll\Housing - Copy.csv")
read_csv
# Out:
#           price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000.0   7420       4.0          2        3      yes        no
# 1    12250000.0   8960       4.0          4        4      yes        no
# 2    12250000.0   9960       3.0          2        2      yes        no
# 3    12215000.0   7500       4.0          2        2      yes        no
# 4    11410000.0   7420       4.0          1        2      yes       yes
# 5    10850000.0   7500       3.0          3        1      yes        no
# 6    10150000.0   8580       4.0          3        4      yes        no
# 7    10150000.0  16200       5.0          3        2      yes        no
# 8     9870000.0   8100       NaN          1        2      yes       yes
# 9     9800000.0   5750       NaN          2        4      yes       yes
# 10    9800000.0  13200       NaN          1        2      yes        no
# 11    9681000.0   6000       NaN          3        2      yes       yes
# ...

# %%
read_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
# price               516 non-null float64
# area                545 non-null int64
# bedrooms            534 non-null float64
# bathrooms           545 non-null int64
# stories             545 non-null int64
# mainroad            545 non-null object
# guestroom           545 non-null object
# basement            10 non-null object
# hotwaterheating     545 non-null object
# airconditioning     545 non-null object
# parking             545 non-null int64
# prefarea            545 non-null object
# furnishingstatus    120 non-null object
# dtypes: float64(2), int64(4), object(7)
# memory usage: 55.4+ KB

# %%
read_csv.shape
# Out:
# (545, 13)

# %%
read_csv.isnull()
# Out:
#      price   area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    False  False     False      False    False     False      False
# 1    False  False     False      False    False     False      False
# 2    False  False     False      False    False     False      False
# 3    False  False     False      False    False     False      False
# 4    False  False     False      False    False     False      False
# 5    False  False     False      False    False     False      False
# 6    False  False     False      False    False     False      False
# 7    False  False     False      False    False     False      False
# 8    False  False      True      False    False     False      False
# 9    False  False      True      False    False     False      False
# 10   False  False      True      False    False     False      False
# 11   False  False      True      False    False     False      False
# 12   False  False      True      False    False     False      False
# ...

# %%
nan = read_csv.isnull().sum()

# %%
parcentage = nan/read_csv.shape[0]*100
parcentage
# Out:
# price                5.321101
# area                 0.000000
# bedrooms             2.018349
# bathrooms            0.000000
# stories              0.000000
# mainroad             0.000000
# guestroom            0.000000
# basement            98.165138
# hotwaterheating      0.000000
# airconditioning      0.000000
# parking              0.000000
# prefarea             0.000000
# furnishingstatus    77.981651
# dtype: float64

# %%
drop_c = parcentage[parcentage>40]
drop_c
# Out:
# basement            98.165138
# furnishingstatus    77.981651
# dtype: float64

# %%
drop_columns = read_csv.drop(columns=drop_c.keys())
drop_Columns
# Out:
#           price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000.0   7420       4.0          2        3      yes        no
# 1    12250000.0   8960       4.0          4        4      yes        no
# 2    12250000.0   9960       3.0          2        2      yes        no
# 3    12215000.0   7500       4.0          2        2      yes        no
# 4    11410000.0   7420       4.0          1        2      yes       yes
# 5    10850000.0   7500       3.0          3        1      yes        no
# 6    10150000.0   8580       4.0          3        4      yes        no
# 7    10150000.0  16200       5.0          3        2      yes        no
# 8     9870000.0   8100       NaN          1        2      yes       yes
# 9     9800000.0   5750       NaN          2        4      yes       yes
# 10    9800000.0  13200       NaN          1        2      yes        no
# 11    9681000.0   6000       NaN          3        2      yes       yes
# ...

# %%
sns.heatmap(drop_Columns.isnull())

# %%
drops_row = drop_Columns.dropna()

# %%
sns.heatmap(drop_rows.isnull())

# %%
int_float_obj = drop_rows.select_dtypes(["int64","float64"]).columns
int_float_obj
# Out:
# Index([u'price', u'area', u'bedrooms', u'bathrooms', u'stories', u'parking'], dtype='object')

# %%
plt.figure(figsize=(25,25))
for i in range (len(int_float_obj)):
    plt.subplot(4,9,i+1)
    sns.distplot(drops_row[int_float_obj[i]],bins=20)

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\Users\musfik\Downloads\mlllllll\Housing - Copy.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
# price               516 non-null float64
# area                545 non-null int64
# bedrooms            534 non-null float64
# bathrooms           545 non-null int64
# stories             545 non-null int64
# mainroad            545 non-null object
# guestroom           545 non-null object
# basement            10 non-null object
# hotwaterheating     545 non-null object
# airconditioning     545 non-null object
# parking             545 non-null int64
# prefarea            545 non-null object
# furnishingstatus    120 non-null object
# dtypes: float64(2), int64(4), object(7)
# memory usage: 55.4+ KB

# %%
df.shape
# Out:
# (545, 13)

# %%
nul_valuse = df.isnull().sum()

# %%
parcentage = nul_valuse[nul_valuse>40].keys()

# %%
sns.heatmap(df.isnull())

# %%
drop_columns1 = df.drop(columns=parcentage)

# %%
sns.heatmap(drop_columns1.isnull())

# %%
drop_rows1 = drop_columns1.dropna()

# %%
sns.heatmap(drop_rows1.isnull())

# %%
int_float1 = drop_rows1.select_dtypes(["int64","float64","int32","float32"]).columns
int_float2 = df.select_dtypes(["int64","float64","int32","float64"]).columns

# %%
plt.figure(figsize=(25,25))
for i in range(len(int_float1)):
    plt.subplot(9,4,i+1)
    sns.distplot(drop_rows1[int_float1[i]])

# %%
print(int_float2)
# Out:
# Index([u'price', u'area', u'bedrooms', u'bathrooms', u'stories', u'parking'], dtype='object')

# %%
print(int_float2[0])
# Out:
# price

# %%
d = df[int_float2[0]]

# %%
type(d)
# Out:
# pandas.core.series.Series

# %%
d1 = pd.Series([1,2,3,4])
sns.distplot(d1,bins=20)
